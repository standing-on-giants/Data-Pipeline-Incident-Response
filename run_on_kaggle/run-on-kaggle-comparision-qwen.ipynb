# %% [markdown]
# # Kaggle Environment Setup for Qwen2.5-3B Model Comparison
# This notebook sets up the Kaggle environment, clones the repository, installs dependencies, and evaluates the Base, SFT, and GRPO variants of the Qwen dataset side-by-side using the identical evaluation pipeline.

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN_DEVARMANI")

# !rm -rf Meta_hackathon
# !git clone -b dev/pratham --single-branch https://{token}@github.com/standing-on-giants/Meta_hackathon.git
# Out:
# Cloning into 'Meta_hackathon'...
# remote: Enumerating objects: 454, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 454 (delta 60), reused 87 (delta 38), pack-reused 337 (from 1)
# Receiving objects: 100% (454/454), 889.13 KiB | 7.60 MiB/s, done.
# Resolving deltas: 100% (285/285), done.

# %%
# Navigate to directory and install requirements
# %cd /kaggle/working/Meta_hackathon
# !pip install -q transformers accelerate bitsandbytes peft python-dotenv
# Out:
# /kaggle/working/Meta_hackathon
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 27.5 MB/s eta 0:00:00:00:0100:01

# %%
# Run the inference comparison script and save results to output.txt
# !python /kaggle/working/Meta_hackathon/inference_qwen_comparison_GRPO_vs_og.py --models grpo | tee output.txt
# Out:
# [19:49:43] Bootstrapping comparison run
# ...
# Qwen2.5-3B  |  Inference Comparison  (LoRA adapter loading)
#   Models to run : ['grpo']
#   Tasks         : ['easy', 'medium', 'hard', 'hard2']
#   Max steps/ep  : 25
#   Quantization  : float16
#   Base model    : Qwen/Qwen2.5-3B-Instruct
#   SFT LoRA      : Abhinav-hf/qwen-grpo-sft-trained-16bit
#   GRPO LoRA     : Abhinav-hf/qwen-grpo-lora-adapters
# ...
# [19:49:43] Starting shared base model load
# [19:49:43] Loading base model in float16: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 434/434 [00:04<00:00, 104.81it/s, Materializing param=m
# [19:50:16] Base model loaded (float16)
# [SKIP] Base model (not in --models)
# [SKIP] SFT model (not in --models)
#
# --- Loading GRPO (LoRA) ---
# [19:50:16] Starting GRPO adapter load
# [19:50:16] Loading LoRA tokenizer: Abhinav-hf/qwen-grpo-lora-adapters
# [19:50:20] LoRA tokenizer loaded
# ...
